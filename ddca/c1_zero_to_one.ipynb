# %% [markdown]
# # Chapter 1: From Zero to Hero
# - Here we brush on the very basics as the main introduction to this book.

# %%
# Chapter

# %%
import numpy as np

# %% [markdown]
# ## Exercises
#
# **E1.4**: An analog voltage is in the range of 0–5 V. If it can be measured
# with an accuracy of ±50 mV, at most how many bits of information does it
# convey?
#
# ±50 mV range implies that every step can be 100 mV in total. In a range of 0-5 V, we have $\frac{50}{100 mV} = 50$ intervals. Therefore it contains $\log_2 (50) = 5.64$ bits of information. Or rather we can correctly represent all in 6 bits (round up).

# %% [markdown]
# **E1.5** A classroom has an old clock on the wall whose minute hand broke
# off.
#
# (a) If you can read the hour hand to the nearest 15 minutes, how many bits of
# information does the clock convey about the time?
#
# (b) If you know whether it is before or after noon, how many additional bits of
# information do you know about the time?
#
# (a) If each hour is can be read in the nearest 15 mins, that means 1 hour is 4 points then in one whole clock (12-hour clock) there are $4 \times 12 = 48$ points. Thus we have: $\log_2 (48) = 5.58$ bits. Or round up to 6.
#
# (b) Representing day or afternoon only needs 1 bit of information

# %% [markdown]
# **E1.6** The Babylonians developed the sexagesimal (base 60) number system about 4000 years ago. How many bits of information is conveyed with one sexagesimal digit? How do you write the number $4000_{10}$ in sexagesimal?
#
# 60 elements then results in $\log_2 (60) = 5.9068$.
#
# Then to write $4000_{10}$ in sexagesimal we can do couinting by 60s. $1 \cdot 60^2 + 6 \cdot 60^1 + 40 \cdot 60^0 = 4000_{10}$ therefore we have ${1, 6, 40}$

# %% [markdown]
# **E1.7** How many different numbers can be represented with 16 bits?
#
# That is a total of $2^{17} = 65,536$

# %% [markdown]
# **E1.8** What is the largest unsigned 32-bit binary number?
#
# $2^{32}-1= 4,294,967,295$. The minus 1 is because the smallest number starts at 0 and not 1.

# %% [markdown]
# **E1.9** What is the largest 16-bit binary number that can be represented with:
#
# (a) unsigned numbers?
#
# (b) 2's complement?
#
# (c) sign magntiude?
#
# (a) Unsigned is $2^{16}-1 = 63,536$
#
# (b) 2's complement range is $[-2^{N-1}, 2^{N-1}-1]$ therefore we have $2^{15}-1=32,767$
#
# (c) sign magnitude range is $[-2^{N-1}-1, 2^{N-1}-1]$ therefore we have $2^{15}-1=32,767$

# %% [markdown]
# **E1.9** What is the largest 32-bit binary number that can be represented with:
#
# (a) unsigned numbers?
#
# (b) 2's complement?
#
# (c) sign magntiude?
#
# (a) Unsigned is $2^{32}-1= 4,294,967,295$
#
# (b) 2's complement range is $[-2^{N-1}, 2^{N-1}-1]$ therefore we have $2^{31}-1= 2,147,483,647$
#
# (c) sign magnitude range is $[-2^{N-1}-1, 2^{N-1}-1]$ therefore we have $2^{31}-1= 2,147,483,647$

# %% [markdown]
# **E1.11** What is the smallest (most negative) 16-bit binary number that can be represented with:
#
# (a) unsigned numbers?
#
# (b) 2's complement?
#
# (c) sign magntiude?
#
# (a) Unsigned is always $0$.
#
# (b) 2's complement range is $[-2^{N-1}, 2^{N-1}-1]$ therefore we have $-2^{15}=-32,768$
#
# (c) sign magnitude range is $[-2^{N-1}-1, 2^{N-1}-1]$ therefore we have $-2^{15}-1=-32,767$

# %% [markdown]
# **E1.12** What is the smallest (most negative) 32-bit binary number that can be represented with:
#
# (a) unsigned numbers?
#
# (b) 2's complement?
#
# (c) sign magntiude?
#
# (a) Unsigned is always $0$.
#
# (b) 2's complement range is $[-2^{N-1}, 2^{N-1}-1]$ therefore we have $-2^{31}=-2,147,483,648$
#
# (c) sign magnitude range is $[-2^{N-1}-1, 2^{N-1}-1]$ therefore we have $-2^{31}-1=-2,147,483,647$

# %% [markdown]
# **E1.13** Convert the following unsigned binary numbers to decimal. Show your work.
#
# (a) $1010_2$
#
# (b) $110110_2$
#
# (c) $11110000_2$
#
# (d) $000100010100111_2$
#
# (a) $2^3 + 2^1 = 8 + 2 =10$
#
# (b) $2^5 + 2^4 + 2^2 + 2^1 = 32 + 16 + 4 + 2 = 54$
#
# (c) $2^7 + 2^6 + 2^5 + 2^4 = 128 + 64 + 32 + 16 =240$
#
# (d) $2^11 + 2^7 + 2^5 + 2^2 + 2^1 + 2^0 = 2048 + 128 + 32 + 4 + 2 + 1 = 2215$

# %% [markdown]
# **E1.14** Convert the following unsigned binary numbers to decimal. Show your work.
#
# (a) $1110_2$
#
# (b) $100100_2$
#
# (c) $11010111_2$
#
# (d) $011101010100100_2$
#
# (a) $2^3 + 2^2 + 2^1 = 8 + 4 + 2 = 14$
#
# (b) $2^5 + 2^2 = 32 + 4 = 36$
#
# (c) $2^7 + 2^6 + 2^4 + 2^2 + 2^1 + 2^0 = 128 + 64 + 16 + 4 + 2 + 1 = 215$
#
# (d) $2^{13} + 2^{12} + 2^{11} + 2^9 + 2^7 + 2^5 + 2^2 = 8192 + 4096 + 2048 + 512 + 128 + 32 + 4 = 15,012$

# %% [markdown]
# **E1.15** Repeat Exercise 1.13, but convert to hexadecimal.
#
# I prefer to work by observing the bits. Since it is known beforehand which bit values correspond to which hex values.
#
# (a) $1010_2 = \textrm{A}_{16}$
#
# (b) $110110_2 = \textrm{36}_{16}$
#
# (c) $11110000_2 = \textrm{F0}_{16}$
#
# (d) $000100010100111_2 = \textrm{08A7}_{16}$
#
# **E1.16** Repeat Exercise 1.14, but convert to hexadecimal.
#
# Same as above.
#
# (a) $1110_2 = \textrm{E}_{16}$
#
# (b) $100100_2 = \textrm{24}_{16}$
#
# (c) $11010111_2 = \textrm{D7}_{16}$
#
# (d) $011101010100100_2 = \textrm{3AA4}_{16}$

# %% [markdown]
# **E1.17** Convert the following hexadecimal numbers to decimal. Show your work.
#
# (a) $\textrm{A5}_{16}$
#
# (b) $\textrm{3B}_{16}$
#
# (c) $\textrm{FFFF}_{16}$
#
# (d) $\textrm{D0000000}_{16}$
#
# The solutions for each item simply needs to convert the decimal equivalent $ D \times 16^{N}$ where $D$ is the decimal and $N$ is the hex position.
#
# (a) $\textrm{A5}_{16} = 10 \cdot 16^{1} + 5 \cdot 16^{0} = 160 + 5 = 165$
#
# (b) $\textrm{3B}_{16} = 3 \cdot 16^{1} + 11 \cdot 16^{0} = 48 + 11 = 59$
#
# (c) $\textrm{FFFF}_{16} = 15 \cdot 16^{3} + 15 \cdot 16^{2} + 15 \cdot 16^{1} + 15 \cdot 16^{0} = 61440 + 3840 + 240 + 15 = 65,536$
#
# (d) $\textrm{D0000000}_{16} = 13 \cdot 16^{7} = 3,489,660,928$

# %% [markdown]
# **E1.18** Convert the following hexadecimal numbers to decimal. Show your work.
#
# (a) $\textrm{4E}_{16}$
#
# (b) $\textrm{7C}_{16}$
#
# (c) $\textrm{ED3A}_{16}$
#
# (d) $\textrm{403FB001}_{16}$
#
# The solutions for each item simply needs to convert the decimal equivalent $ D \times 16^{N}$ where $D$ is the decimal and $N$ is the hex position.
#
# (a) $\textrm{4E}_{16} = 4 \cdot 16^{1} + 14 \cdot 16^{0} = 64 + 14 = 78$
#
# (b) $\textrm{7C}_{16} = 7 \cdot 16^{1} + 12 \cdot 16^{0} = 112 + 12 = 124$
#
# (c) $\textrm{ED3A}_{16} = 14 \cdot 16^{3} + 13 \cdot 16^{2} + 3 \cdot 16^{1} + 10 \cdot 16^{0} = 57,344 + 3,328 + 48 + 10 = 60,730$
#
# (d) $\textrm{403FB001}_{16} =  4 \cdot 16^{7} + 3 \cdot 16^{5} + 15 \cdot 16^{4} + 11 \cdot 16^{3} +  1 \cdot 16^{0} =  1,077,915,649$

# %% [markdown]
# **E1.19** Repeat Exercise 1.17, but convert to unsigned binary.
#
# (a) $\textrm{A5}_{16} = 10100101_{2}$
#
# (b) $\textrm{3B}_{16} = 00111011_{2}$
#
# (c) $\textrm{FFFF}_{16} = 1111111111111111_{2}$
#
# (d) $\textrm{D0000000}_{16} = 11010000000000000000000000000000_{2}$

# %% [markdown]
# **E1.20** Repeat Exercise 1.18, but convert to unsigned binary.
#
# (a) $\textrm{4E}_{16} = 01001110_{2}$
#
# (b) $\textrm{7C}_{16} = 01111100_{2}$
#
# (c) $\textrm{ED3A}_{16} = 1110110100111010_{2}$
#
# (d) $\textrm{403FB001}_{16} = 01000000001111111011000000000001_{2}$

# %% [markdown]
# **E1.21** Convert the following two’s complement binary numbers to decimal.
#
# Here, we will give the answer write away but the processes are the same, (1) check the sign, if negative then do an invert + 1 two's complement. Otherwise just consider the LSBs that exclude the very most MSB.
#
# (a) $1010_2 = -6$
#
# (b) $110110_2 = $
#
# (c) $01110000_2 = $
#
# (d) $10011111_2 = $
